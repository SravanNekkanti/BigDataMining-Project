# %%
import pandas as pd
import numpy as np

# %%
accidents_df = pd.read_csv("D:\\UIC\\Fall 2023 Project\\US_Accidents\\US_Accidents_March23.csv")

# %%
accidents_df.head()
# Out:
#     ID   Source  Severity           Start_Time             End_Time  \
# 0  A-1  Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  Distance(mi)  ... Roundabout  \
# 0  39.865147 -84.058723      NaN      NaN          0.01  ...      False
# 1  39.928059 -82.831184      NaN      NaN          0.01  ...      False
# 2  39.063148 -84.032608      NaN      NaN          0.01  ...      False
# 3  39.747753 -84.205582      NaN      NaN          0.01  ...      False
# 4  39.627781 -84.188354      NaN      NaN          0.01  ...      False
#
#   Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# ...

# %% [markdown]
# ### DATA INSPECTION

# %%
accidents_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 46 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             object
#  4   End_Time               object
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   End_Lat                float64
#  8   End_Lng                float64
#  9   Distance(mi)           float64
#  10  Description            object
#  11  Street                 object
#  12  City                   object
#  13  County                 object
#  14  State                  object
#  15  Zipcode                object
#  16  Country                object
#  17  Timezone               object
#  18  Airport_Code           object
#  19  Weather_Timestamp      object
#  20  Temperature(F)         float64
# ...

# %%
accidents_df.isnull().sum()
# Out:
# ID                             0
# Source                         0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                  3402762
# End_Lng                  3402762
# Distance(mi)                   0
# Description                    5
# Street                     10869
# City                         253
# County                         0
# State                          0
# Zipcode                     1915
# Country                        0
# Timezone                    7808
# Airport_Code               22635
# Weather_Timestamp         120228
# Temperature(F)            163853
# Wind_Chill(F)            1999019
# Humidity(%)               174144
# Pressure(in)              140679
# Visibility(mi)            177098
# Wind_Direction            175206
# Wind_Speed(mph)           571233
# Precipitation(in)        2203586
# ...

# %%
accidents_df.shape
# Out:
# (7728394, 46)

# %%
#pd.set_option('display.max_rowwidth', None)
pd.reset_option('display.max_rows', None)

# %%
zipcode_unique = accidents_df['Zipcode'].unique().tolist()
print(len(zipcode_unique))
zipcode_unique

# %%
accidents_df1 = accidents_df
# making a copy

# %%
accidents_df1['mean_lat'] = accidents_df1.groupby('Zipcode')['End_Lat'].transform('mean')

# %%
accidents_df1['mean_lng'] = accidents_df1.groupby('Zipcode')['End_Lng'].transform('mean')

# %%
accidents_df1['End_Lat'].fillna(accidents_df1['mean_lat'], inplace=True)
accidents_df1['End_Lng'].fillna(accidents_df1['mean_lng'], inplace=True)

# %%
accidents_df1.isnull().sum()

# %%
accidents_df1.head()
# Out:
#     ID   Source  Severity           Start_Time             End_Time  \
# 0  A-1  Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng    End_Lat    End_Lng  Distance(mi)  ...   Stop  \
# 0  39.865147 -84.058723  39.848386 -84.097273          0.01  ...  False
# 1  39.928059 -82.831184        NaN        NaN          0.01  ...  False
# 2  39.063148 -84.032608  39.062109 -84.022972          0.01  ...  False
# 3  39.747753 -84.205582  39.744192 -84.218929          0.01  ...  False
# 4  39.627781 -84.188354  39.644863 -84.172444          0.01  ...  False
#
#   Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset Civil_Twilight  \
# ...

# %%
accidents_df1.shape
# Out:
# (7728394, 48)

# %%
accidents_df1['State'].value_counts()
# Out:
# State
# CA    1741433
# FL     880192
# TX     582837
# SC     382557
# NY     347960
# NC     338199
# VA     303301
# PA     296620
# MN     192084
# OR     179660
# AZ     170609
# GA     169234
# IL     168958
# TN     167388
# MI     162191
# LA     149701
# NJ     140719
# MD     140417
# OH     118115
# WA     108221
# AL     101044
# UT      97079
# CO      90885
# OK      83647
# MO      77323
# CT      71005
# IN      67224
# MA      61996
# WI      34688
# KY      32254
# NE      28870
# MT      28496
# IA      26307
# AR      22780
# NV      21665
# KS      20992
# DC      18630
# RI      16971
# MS      15181
# DE      14097
# WV      13793
# ID      11376
# NM      10325
# NH      10213
# WY       3757
# ND       3487
# ME       2698
# VT        926
# SD        289
# Name: count, dtype: int64

# %%
weather_unique = accidents_df['Weather_Timestamp'].unique().tolist()
print(len(weather_unique))
# Out:
# 941332

# %%
accidents_df1.columns
# Out:
# Index(['ID', 'Source', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat',
#        'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Description',
#        'Street', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight', 'mean_lat', 'mean_lng'],
#       dtype='object')

# %%
accidents_df1['Weather_Timestamp'] = pd.to_datetime(accidents_df1['Weather_Timestamp'])

accidents_df1['month'] = accidents_df1['Weather_Timestamp'].dt.month

accidents_df1['mean_temp_by_month'] = accidents_df1.groupby(['Zipcode', 'month'])['Temperature(F)'].transform('mean')
accidents_df1['mean_windchill_by_month'] = accidents_df1.groupby(['Zipcode', 'month'])['Wind_Chill(F)'].transform('mean')
accidents_df1['mean_humidity_by_month'] = accidents_df1.groupby(['Zipcode', 'month'])['Humidity(%)'].transform('mean')
accidents_df1['mean_pressure_by_month'] = accidents_df1.groupby(['Zipcode', 'month'])['Pressure(in)'].transform('mean')
accidents_df1['mean_visibility_by_month'] = accidents_df1.groupby(['Zipcode', 'month'])['Visibility(mi)'].transform('mean')
accidents_df1['mean_windspeed_by_month'] = accidents_df1.groupby(['Zipcode', 'month'])['Wind_Speed(mph)'].transform('mean')
accidents_df1['mean_precipitation_by_month'] = accidents_df1.groupby(['Zipcode', 'month'])['Precipitation(in)'].transform('mean')

# %%
accidents_df1.columns
# Out:
# Index(['ID', 'Source', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat',
#        'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Description',
#        'Street', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight', 'mean_lat', 'mean_lng', 'month',
#        'mean_temp_by_month', 'mean_windchill_by_month',
#        'mean_humidity_by_month', 'mean_pressure_by_month',
#        'mean_visibility_by_month', 'mean_windspeed_by_month',
#        'mean_precipitation_by_month'],
# ...

# %%
accidents_df1['Temperature(F)'].fillna(accidents_df1['mean_temp_by_month'], inplace=True)
accidents_df1['Wind_Chill(F)'].fillna(accidents_df1['mean_windchill_by_month'], inplace=True)
accidents_df1['Humidity(%)'].fillna(accidents_df1['mean_humidity_by_month'], inplace=True)
accidents_df1['Pressure(in)'].fillna(accidents_df1['mean_pressure_by_month'], inplace=True)
accidents_df1['Visibility(mi)'].fillna(accidents_df1['mean_visibility_by_month'], inplace=True)
accidents_df1['Wind_Speed(mph)'].fillna(accidents_df1['mean_windspeed_by_month'], inplace=True)
accidents_df1['Precipitation(in)'].fillna(accidents_df1['mean_precipitation_by_month'], inplace=True)

# %%
accidents_df1.isnull().sum()
# Out:
# ID                                  0
# Source                              0
# Severity                            0
# Start_Time                          0
# End_Time                            0
# Start_Lat                           0
# Start_Lng                           0
# End_Lat                        622091
# End_Lng                        622091
# Distance(mi)                        0
# Description                         5
# Street                          10869
# City                              253
# County                              0
# State                               0
# Zipcode                          1915
# Country                             0
# Timezone                         7808
# Airport_Code                    22635
# Weather_Timestamp              120228
# Temperature(F)                 127444
# Wind_Chill(F)                  549552
# Humidity(%)                    129662
# Pressure(in)                   123524
# Visibility(mi)                 142598
# ...

# %%
accidents_df1 = accidents_df1.drop(columns = ['mean_temp_by_month','mean_windchill_by_month','mean_humidity_by_month','mean_pressure_by_month','mean_visibility_by_month','mean_windspeed_by_month','mean_precipitation_by_month'])

# %%
accidents_df1 = accidents_df1.drop(columns = ['Civil_Twilight','Nautical_Twilight','Astronomical_Twilight'])

# %%
accidents_df1 = accidents_df1.drop(columns = ['mean_lat','mean_lng'])

# %%
accidents_df1 = accidents_df1.dropna(subset=['Description'])

# %%
accidents_df1.isnull().sum()
# Out:
# ID                        0
# Source                    0
# Severity                  0
# Start_Time                0
# End_Time                  0
# Start_Lat                 0
# Start_Lng                 0
# End_Lat              622091
# End_Lng              622091
# Distance(mi)              0
# Description               0
# Street                10869
# City                    253
# County                    0
# State                     0
# Zipcode                1915
# Country                   0
# Timezone               7808
# Airport_Code          22635
# Weather_Timestamp    120228
# Temperature(F)       127444
# Wind_Chill(F)        549552
# Humidity(%)          129662
# Pressure(in)         123524
# Visibility(mi)       142598
# Wind_Direction       175205
# Wind_Speed(mph)      213688
# Precipitation(in)    721518
# Weather_Condition    173459
# Amenity                   0
# Bump                      0
# Crossing                  0
# Give_Way                  0
# ...

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
accidents_df1.isnull().sum()
# Out:
# ID                        0
# Source                    0
# Severity                  0
# Start_Time                0
# End_Time                  0
# Start_Lat                 0
# Start_Lng                 0
# End_Lat              622091
# End_Lng              622091
# Distance(mi)              0
# Description               0
# Street                10869
# City                    253
# County                    0
# State                     0
# Zipcode                1915
# Country                   0
# Timezone               7808
# Airport_Code          22635
# Weather_Timestamp    120228
# Temperature(F)       127444
# Wind_Chill(F)        549552
# Humidity(%)          129662
# Pressure(in)         123524
# Visibility(mi)       142598
# Wind_Direction       175205
# Wind_Speed(mph)      213688
# Precipitation(in)    721518
# Weather_Condition    173459
# Amenity                   0
# Bump                      0
# Crossing                  0
# Give_Way                  0
# ...

# %%
city_dataframes = {city: group for city, group in accidents_df1.groupby('City')}
for each_city in city_dataframes:
    print(each_city)

# %%
city_record_counts = {}

for city, city_df in city_dataframes.items():
    record_count = len(city_df)
    city_record_counts[city] = record_count

city_record_counts_file = "city_record_counts.txt"

# You can print the record counts for each city:
with open(city_record_counts_file, 'w') as file:
    for city, count in city_record_counts.items():
        file.write(f"City: {city}, Record Count: {count}\n")

# %%
major_cities_dataframes = {}
other_cities_dataframe = pd.DataFrame()

major_threshold = 10000

for city, city_df in city_dataframes.items():
    if len(city_df) > major_threshold:
        major_cities_dataframes[city] = city_df
    else:
        other_cities_dataframe = pd.concat([other_cities_dataframe, city_df])

major_cities_csv_filename = "major_cities.csv"
other_cities_csv_filename = "other_cities.csv"

for city, city_df in major_cities_dataframes.items():
    city_df.to_csv(f"{major_cities_csv_filename[:-4]}_{city}.csv", index=False)

other_cities_dataframe.to_csv(other_cities_csv_filename, index=False)

print(f"Major cities data saved to {major_cities_csv_filename}")
print(f"Other cities data saved to {other_cities_csv_filename}")
# Out:
# Major cities data saved to major_cities.csv
# Other cities data saved to other_cities.csv

# %%
charlotte_df = pd.read_csv("D:\\UIC\\Fall 2023 Project\\major_cities_Charlotte.csv")
charlotte_df.isnull().sum()
# Out:
# ID                       0
# Source                   0
# Severity                 0
# Start_Time               0
# End_Time                 0
# Start_Lat                0
# Start_Lng                0
# End_Lat              16342
# End_Lng              16342
# Distance(mi)             0
# Description              0
# Street                 126
# City                     0
# County                   0
# State                    0
# Zipcode                  0
# Country                  0
# Timezone                 0
# Airport_Code             8
# Weather_Timestamp      161
# Temperature(F)         169
# Wind_Chill(F)        14223
# Humidity(%)            170
# Pressure(in)           162
# Visibility(mi)         188
# Wind_Direction         429
# Wind_Speed(mph)       2221
# Precipitation(in)    14155
# Weather_Condition      225
# Amenity                  0
# Bump                     0
# Crossing                 0
# Give_Way                 0
# Junction                 0
# ...

# %%
charlotte_df.head()
# Out:
#          ID   Source  Severity          Start_Time             End_Time  \
# 0  A-179811  Source2         3 2016-12-11 09:06:33  2016-12-11 09:34:47
# 1  A-183241  Source2         2 2017-01-23 07:44:33  2017-01-23 08:14:16
# 2  A-368869  Source2         3 2017-03-13 12:36:24  2017-03-13 13:06:01
# 3  A-370195  Source2         3 2017-04-01 01:29:55  2017-04-01 01:58:03
# 4  A-474225  Source2         3 2017-06-23 14:32:55  2017-06-23 15:02:01
#
#    Start_Lat  Start_Lng    End_Lat    End_Lng  Distance(mi)  \
# 0  42.658440 -84.684502  42.560736 -84.808838          0.01
# 1  42.523258 -84.895012  42.560736 -84.808838          0.01
# 2  42.516399 -84.835884  42.560736 -84.808838          0.01
# 3  42.575329 -84.819725  42.560736 -84.808838          0.01
# 4  42.575329 -84.819725  42.560736 -84.808838          0.00
#
#                                          Description        Street       City  \
# 0  Entry ramp closed due to accident on I-69 Nort...        I-69 S  Charlotte
# ...

# %%
from haversine import haversine
import pandas as pd
import numpy as np

missing_temp_in_charlotte_df = charlotte_df[charlotte_df['Temperature(F)'].isna()]

for index, each_missing_entry in missing_temp_in_charlotte_df.iterrows():
    charlotte_df['Distance'] = charlotte_df.apply(lambda row: haversine((each_missing_entry['Start_Lat'], each_missing_entry['Start_Lng']), (row['Start_Lat'], row['Start_Lng'])), axis=1)
    
    nearby_entries = charlotte_df[charlotte_df['Distance'] <= 5]

    missing_date = pd.to_datetime(each_missing_entry['Start_Time'], format='mixed').date()

    three_day_entries = nearby_entries[pd.to_datetime(nearby_entries['Start_Time'], format='mixed').apply(lambda x: abs((x.date() - missing_date).days) <= 1)]

    if not three_day_entries.empty:
        average_temp = three_day_entries['Temperature(F)'].mean()
        charlotte_df.loc[index, 'Temperature(F)'] = average_temp

# %%
charlotte_df.isnull().sum()
# Out:
# ID                       0
# Source                   0
# Severity                 0
# Start_Time               0
# End_Time                 0
# Start_Lat                0
# Start_Lng                0
# End_Lat              16342
# End_Lng              16342
# Distance(mi)             0
# Description              0
# Street                 126
# City                     0
# County                   0
# State                    0
# Zipcode                  0
# Country                  0
# Timezone                 0
# Airport_Code             8
# Weather_Timestamp      161
# Temperature(F)           6
# Wind_Chill(F)        14223
# Humidity(%)            170
# Pressure(in)           162
# Visibility(mi)         188
# Wind_Direction         429
# Wind_Speed(mph)       2221
# Precipitation(in)    14155
# Weather_Condition      225
# Amenity                  0
# Bump                     0
# Crossing                 0
# Give_Way                 0
# Junction                 0
# ...

# %%
from haversine import haversine
import pandas as pd
import numpy as np

missing_wind_chill_in_charlotte_df = charlotte_df[charlotte_df['Wind_Chill(F)'].isna()]

for index, each_missing_entry in missing_wind_chill_in_charlotte_df.iterrows():
    charlotte_df['Distance'] = charlotte_df.apply(lambda row: haversine((each_missing_entry['Start_Lat'], each_missing_entry['Start_Lng']), (row['Start_Lat'], row['Start_Lng'])), axis=1)
    
    nearby_entries = charlotte_df[charlotte_df['Distance'] <= 5]

    missing_date = pd.to_datetime(each_missing_entry['Start_Time'], format='mixed').date()

    three_day_entries = nearby_entries[pd.to_datetime(nearby_entries['Start_Time'], format='mixed').apply(lambda x: abs((x.date() - missing_date).days) <= 1)]

    if not three_day_entries.empty:
        average_wind_chill = three_day_entries['Wind_Chill(F)'].mean()
        charlotte_df.loc[index, 'Wind_Chill(F)'] = average_wind_chill

# %%
charlotte_df.isnull().sum()
# Out:
# ID                       0
# Source                   0
# Severity                 0
# Start_Time               0
# End_Time                 0
# Start_Lat                0
# Start_Lng                0
# End_Lat              16342
# End_Lng              16342
# Distance(mi)             0
# Description              0
# Street                 126
# City                     0
# County                   0
# State                    0
# Zipcode                  0
# Country                  0
# Timezone                 0
# Airport_Code             8
# Weather_Timestamp      161
# Temperature(F)           6
# Wind_Chill(F)          168
# Humidity(%)            170
# Pressure(in)           162
# Visibility(mi)         188
# Wind_Direction         429
# Wind_Speed(mph)       2221
# Precipitation(in)    14155
# Weather_Condition      225
# Amenity                  0
# Bump                     0
# Crossing                 0
# Give_Way                 0
# Junction                 0
# ...

# %%
other_cities_df = pd.read_csv("D:\\UIC\\Fall 2023 Project\\other_cities.csv")
other_cities_df.isnull().sum()
# Out:
# ID                        0
# Source                    0
# Severity                  0
# Start_Time                0
# End_Time                  0
# Start_Lat                 0
# Start_Lng                 0
# End_Lat              313295
# End_Lng              313295
# Distance(mi)              0
# Description               0
# Street                 6690
# City                      0
# County                    0
# State                     0
# Zipcode                1913
# Country                   0
# Timezone               7800
# Airport_Code          19763
# Weather_Timestamp     91198
# Temperature(F)        96681
# Wind_Chill(F)        317394
# Humidity(%)           98332
# Pressure(in)          93425
# Visibility(mi)       110953
# Wind_Direction       126441
# Wind_Speed(mph)      154025
# Precipitation(in)    443141
# Weather_Condition    131975
# Amenity                   0
# Bump                      0
# Crossing                  0
# Give_Way                  0
# ...
